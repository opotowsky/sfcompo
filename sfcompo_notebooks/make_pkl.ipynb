# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Make a pkl file from different csv downloads from SFCOMPO

# %%
pwr_csv = '../csv/pwr.csv'
bwr_csv = '../csv/bwr.csv'
rst_csv = '../csv/rest.csv'

# %%
pwr_pd = pd.read_csv(pwr_csv)
pwr_pd = pwr_pd[pwr_pd['Reactor name'] != 'Beznau-1']
bwr_pd = pd.read_csv(bwr_csv)
bwr_pd = bwr_pd[bwr_pd['Reactor name']!= 'Dodewaard-1']
rst_pd = pd.read_csv(rst_csv)
sfc = pd.concat([pwr_pd, bwr_pd, rst_pd], ignore_index=True)
pwr_pd.shape, bwr_pd.shape, rst_pd.shape, sfc.shape
# Out:
# ((8926, 17), (8144, 17), (6349, 17), (23419, 17))

# %%
sfc
# Out:
#            Reactor name Reactor type Estimated burnup   e. U235  \
# 0      Calvert Cliffs-1          PWR  12.92 GW*d/tHMi  2.72 wt%
# 1      Calvert Cliffs-1          PWR  14.58 GW*d/tHMi  2.72 wt%
# 2      Calvert Cliffs-1          PWR  18.68 GW*d/tHMi  2.72 wt%
# 3      Calvert Cliffs-1          PWR  18.68 GW*d/tHMi  2.72 wt%
# 4      Calvert Cliffs-1          PWR  18.68 GW*d/tHMi  2.72 wt%
# ...                 ...          ...              ...       ...
# 23414     Pickering A-1        CANDU    221 MW*h/kgUi  0.71 wt%
# 23415     Pickering A-1        CANDU    221 MW*h/kgUi  0.71 wt%
# 23416     Pickering A-1        CANDU    221 MW*h/kgUi  0.71 wt%
# 23417     Pickering A-1        CANDU    221 MW*h/kgUi  0.71 wt%
# 23418     Pickering A-1        CANDU    221 MW*h/kgUi  0.71 wt%
#
#          SFCompo sample ref        Measurement type Sample identifier   Item  \
# 0      CCL-1|D101|MLA098|MM                Activity                MM    C14
# ...

# %%
sfc.to_pickle('sfcompoDB.pkl')
