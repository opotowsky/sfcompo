# %%
import pandas as pd

# %%
df = pd.read_pickle('sfcompo_nuc29_nulls.pkl')

# %%
df.head(2)
# Out:
#                    Burnup  CoolingTime  Enrichment         OrigenReactor  \
# BAL-2|1476|42|15  45100.0          0.0         4.4  Balakovo-2_VVER-1000
# BAL-2|1476|42|31  45800.0          0.0         4.4  Balakovo-2_VVER-1000
#
#                  ReactorType  am241  am242m  am243  cm242   cm244  ...  pu242  \
# BAL-2|1476|42|15         pwr  0.048     NaN  0.141  0.021  0.0550  ...   0.69
# BAL-2|1476|42|31         pwr    NaN     NaN  0.146    NaN  0.0539  ...   0.70
#
#                   sm147  sm149  sm150  sm151  sm152   u234   u235  u236  \
# BAL-2|1476|42|15    NaN    NaN    NaN    NaN    NaN    NaN  10.64  6.17
# BAL-2|1476|42|31    NaN    NaN    NaN    NaN    NaN  0.226  10.66  6.00
#
#                     u238
# BAL-2|1476|42|15  926.55
# BAL-2|1476|42|31  925.00
#
# [2 rows x 34 columns]

# %%
nuc29 = ['am241', 'am242m', 'am243', 'cm242', 'cm244', 
         'cs134', 'cs137', 'eu154', 'nd143', 'nd144', 
         'nd145', 'nd146', 'nd148', 'nd150', 'np237', 
         'pu238', 'pu239', 'pu240', 'pu241', 'pu242', 
         'sm147', 'sm149', 'sm150', 'sm151', 'sm152',
         'u234', 'u235', 'u236', 'u238'
        ]

# %%
avg_vals = {}
for nuc in nuc29:
    avg_vals[nuc] = df[nuc].mean()
avg_vals
# Out:
# {'am241': 0.1882455607399848,
#  'am242m': 0.00087148054017094,
#  'am243': 0.14908689249121085,
#  'cm242': 0.010573426371655347,
#  'cm244': 0.033674899808173606,
#  'cs134': 0.04837191168141593,
#  'cs137': 1.1881963675675675,
#  'eu154': 0.014243353060000002,
#  'nd143': 0.7480474938271605,
#  'nd144': 1.2887430619469027,
#  'nd145': 0.7086605802469136,
#  'nd146': 0.7311663021582734,
#  'nd148': 0.3440919928305454,
#  'nd150': 0.17686704132231404,
#  'np237': 0.5173429369518006,
#  'pu238': 0.17451174509497508,
#  'pu239': 4.7666123136175775,
#  'pu240': 1.8540782456849085,
#  'pu241': 0.8838667113642446,
#  'pu242': 0.5138780585678984,
#  'sm147': 0.2739639175257732,
#  'sm149': 0.003416,
#  'sm150': 0.38234639175257734,
#  'sm151': 0.01286676288659794,
#  'sm152': 0.1321678350515464,
#  'u234': 0.16113017763042253,
#  'u235': 10.669059612346345,
#  'u236': 3.6096157655218613,
#  'u238': 949.5105039827624}

# %%
for nuc in nuc29:
    df[nuc] = df[nuc].fillna(value=avg_vals[nuc])

# %%
df
# Out:
#                        Burnup  CoolingTime  Enrichment         OrigenReactor  \
# BAL-2|1476|42|15      45100.0          0.0         4.4  Balakovo-2_VVER-1000
# BAL-2|1476|42|31      45800.0          0.0         4.4  Balakovo-2_VVER-1000
# BAL-2|1476|42|6       46700.0          0.0         4.4  Balakovo-2_VVER-1000
# BAL-3|1591|23|912     46200.0          0.0         4.4  Balakovo-3_VVER-1000
# BAL-3|1591|23|581     47900.0          0.0         4.4  Balakovo-3_VVER-1000
# ...                       ...          ...         ...                   ...
# YNK-1|E6|NW-A1|G-127  42500.0          0.0         3.4          Yankee-1_PWR
# YNK-1|E6|NW-A1|G-128  42500.0          0.0         3.4          Yankee-1_PWR
# YNK-1|E6|NW-A1|N-21   42600.0          0.0         3.4          Yankee-1_PWR
# YNK-1|E6|NW-A1|T-165  43200.0          0.0         3.4          Yankee-1_PWR
# YNK-1|E6|NW-A1|N-22   44400.0          0.0         3.4          Yankee-1_PWR
#
# ...

# %%
df.to_pickle('sfcompo_nuc29.pkl')
