# %%
import pandas as pd

# %% [markdown]
# ## Aligning SFCOMPO test cases to training set design
#
# ### A. Reactors
# 1. Delete RBMK, MAGNOX, AGR from test set (did not simulate these)
# 2. Ensure ReactorType column matches options from training set, and preserve this information by adding that text to the ReactorName column
#
# ### B. Metadata and other information
# 1. Confirm units match training set (burnup)
# 2. Check script to allow for additional columns (sample ref, etc) as well as OrigenReactor vs. ReactorName
#
# ### C. Isotopes
# 1. Melt isotope concentrations from single column to their own columns.
#   - Using concentration instead of value for unit conformity.
#   - Need to double check, but I think uncertainties apply to 'values' and not 'concentration'
#   - Keeping concentrations, but train set is in g-atoms (moles), so only ratios will be useable until new gram-output training set is simulated.
# 2. Keep only list of 15 nuclides

# %%
pklfile = '~/prep-pkls/nucmoles_opusupdate_aug2019/not-scaled_15nuc.pkl'
sfcompofile = '../clean/sfcompoDB_clean.csv'

# %%
train = pd.read_pickle(pklfile)
test = pd.read_csv(sfcompofile)

# %%
train.head()
# Out:
#               Burnup  CoolingTime  Enrichment OrigenReactor ReactorType  \
# 0.000e+00       0.00     0.000000        0.53       ce14x14         pwr
# 5.733e+01.1  2006.54     0.000839        0.53       ce14x14         pwr
# 5.792e+01    2006.54     0.592485        0.53       ce14x14         pwr
# 5.844e+01    2006.54     1.109213        0.53       ce14x14         pwr
# 6.579e+01    2006.54     8.460400        0.53       ce14x14         pwr
#
#                 ba136   ba138   cs133     cs134   cs135  ...    eu153  \
# 0.000e+00    0.000000  0.0000  0.0000  0.000000  0.0000  ...  0.00000
# 5.733e+01.1  0.000593  0.6109  0.5142  0.002411  0.1187  ...  0.01550
# 5.792e+01    0.000600  0.6114  0.5204  0.002411  0.1209  ...  0.01568
# 5.844e+01    0.000607  0.6114  0.5256  0.002410  0.1224  ...  0.01580
# 6.579e+01    0.000681  0.6114  0.5759  0.002394  0.1238  ...  0.01637
#
#                 eu154  pu239   pu240     pu241     pu242     sm149    sm150  \
# 0.000e+00    0.000000  0.000  0.0000  0.000000  0.000000  0.000000  0.00000
# 5.733e+01.1  0.000451  2.575  0.1198  0.006937  0.000123  0.008141  0.08695
# 5.792e+01    0.000451  2.605  0.1198  0.006937  0.000123  0.009107  0.08695
# 5.844e+01    0.000451  2.627  0.1198  0.006936  0.000123  0.009820  0.08695
# 6.579e+01    0.000450  2.746  0.1198  0.006929  0.000123  0.013470  0.08695
#
#                sm152   total
# 0.000e+00    0.00000  4202.0
# 5.733e+01.1  0.04212  4211.0
# 5.792e+01    0.04212  4211.0
# 5.844e+01    0.04212  4211.0
# 6.579e+01    0.04212  4211.0
#
# [5 rows x 21 columns]

# %%
test.head(5)
# Out:
#              ReactorName ReactorType Fuel type   Burnup BurnupUnit  \
# 10  Balakovo-2_VVER-1000         pwr       UO2  45100.0   MW*d/tUi
# 11  Balakovo-2_VVER-1000         pwr       UO2  45100.0   MW*d/tUi
# 12  Balakovo-2_VVER-1000         pwr       UO2  45100.0   MW*d/tUi
# 13  Balakovo-2_VVER-1000         pwr       UO2  45100.0   MW*d/tUi
# 22  Balakovo-2_VVER-1000         pwr       UO2  45800.0   MW*d/tUi
#
#     Enrichment EnrichmentUnit         SampleRef             Measurement  \
# 10         4.4            wt%  BAL-2|1476|42|15  Isotopic Concentration
# 11         4.4            wt%  BAL-2|1476|42|15  Isotopic Concentration
# 12         4.4            wt%  BAL-2|1476|42|15  Isotopic Concentration
# 13         4.4            wt%  BAL-2|1476|42|15  Isotopic Concentration
# 22         4.4            wt%  BAL-2|1476|42|31  Isotopic Concentration
#
#    Isotope  Value    Unit  Concentration ConcentrationUnit  Sigma  \
# 10   pu239   6.07  mg/gUi           6.07            mg/gUi    2.0
# 11   pu240   2.58  mg/gUi           2.58            mg/gUi    2.0
# 12   pu241   1.70  mg/gUi           1.70            mg/gUi    2.0
# 13   pu242   0.69  mg/gUi           0.69            mg/gUi    2.0
# 22   pu239   6.19  mg/gUi           6.19            mg/gUi    2.0
#
#     Uncertainty UncertaintyUnit
# 10         0.66               %
# 11         0.78               %
# 12         0.59               %
# 13         1.45               %
# 22         0.81               %

# %%
test.ReactorType.unique()
# Out:
# array(['VVER-1000', 'MAGNOX', 'PWR', 'BWR', 'AGR', 'VVER-440', 'RBMK',
#        'CANDU'], dtype=object)

# %%
len(test.SampleRef.unique())
# Out:
# 652

# %% [markdown]
# ### A. Changes to ReactorName and ReactorType

# %%
test = test[(test.ReactorType != 'MAGNOX') & (test.ReactorType != 'AGR') & (test.ReactorType != 'RBMK')]

# %%
test.ReactorType.unique()
# Out:
# array(['VVER-1000', 'PWR', 'BWR', 'VVER-440', 'CANDU'], dtype=object)

# %%
len(test.SampleRef.unique())
# Out:
# 544

# %%
test.ReactorName = test.ReactorName + '_' + test.ReactorType
test.ReactorName
# Out:
# 0        Balakovo-2_VVER-1000
# 1        Balakovo-2_VVER-1000
# 2        Balakovo-2_VVER-1000
# 3        Balakovo-2_VVER-1000
# 4        Balakovo-2_VVER-1000
#                  ...
# 12210            Yankee-1_PWR
# 12211            Yankee-1_PWR
# 12212            Yankee-1_PWR
# 12213            Yankee-1_PWR
# 12214            Yankee-1_PWR
# Name: ReactorName, Length: 9944, dtype: object

# %%
rtypes = {'PWR' : 'pwr', 'BWR' : 'bwr', 'CANDU' : 'phwr', 'VVER-1000' : 'pwr', 'VVER-440' : 'pwr'}
test.ReactorType.replace(rtypes, inplace=True)

# %%
test.rename(columns = {'OrigenReactor' : 'ReactorName'}, inplace = True)

# %% [markdown]
# ### B. Changes to Burnup Units

# %%
# only run once you idiot!
test.Burnup = 1000 * test.Burnup
test.BurnupUnit.unique()
# Out:
# array(['GW*d/tUi'], dtype=object)

# %%
test.BurnupUnit.replace({'GW*d/tUi' : 'MW*d/tUi'}, inplace=True)

# %% [markdown]
# ### C. Matching Iso Column Format

# %%
test.ConcentrationUnit.unique()
# Out:
# array(['mg/gUi'], dtype=object)

# %%
test.Isotope = test.Isotope.str.lower()

# %%
nuc15 = ['cs-133', 'cs134', 'cs135', 'cs137', 'eu153', 
         'eu154', 'ba136', 'ba138', 'sm149', 'sm150', 
         'sm152', 'pu239', 'pu240', 'pu241', 'pu242'
        ]
test = test[test.Isotope.isin(nuc15)]

# %%
df = test[['SampleRef', 'Isotope', 'Concentration']]

# %%
df = df.pivot(index=df.index, columns='Isotope', values='Concentration')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-5764a62d83f1> in <module>
# ----> 1 df = df.pivot(index=df.index, columns='Isotope', values='Concentration')
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5921         from pandas.core.reshape.pivot import pivot
#    5922
# -> 5923         return pivot(self, index=index, columns=columns, values=values)
#    5924
#    5925     _shared_docs[
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     436             index = data.index
#     437         else:
# --> 438             index = data[index]
#     439         index = MultiIndex.from_arrays([index, data[columns]])
#     440
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1637             if missing == len(indexer):
#    1638                 axis_name = self.obj._get_axis_name(axis)
# -> 1639                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1640
#    1641             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Int64Index([   10,    11,    12,    13,    22,    23,    24,    25,    40,\n               41,\n            ...\n            12192, 12193, 12199, 12200, 12201, 12202, 12207, 12208, 12209,\n            12210],\n           dtype='int64', length=3180)] are in the [columns]"

# %%
df.head(50)
# Out:
# Isotope  cs134  cs135  cs137    eu153  eu154  pu239  pu240   pu241   pu242  \
# 10         NaN    NaN    NaN      NaN    NaN  6.070    NaN     NaN     NaN
# 11         NaN    NaN    NaN      NaN    NaN    NaN  2.580     NaN     NaN
# 12         NaN    NaN    NaN      NaN    NaN    NaN    NaN  1.7000     NaN
# 13         NaN    NaN    NaN      NaN    NaN    NaN    NaN     NaN  0.6900
# 22         NaN    NaN    NaN      NaN    NaN  6.190    NaN     NaN     NaN
# 23         NaN    NaN    NaN      NaN    NaN    NaN  2.650     NaN     NaN
# 24         NaN    NaN    NaN      NaN    NaN    NaN    NaN  1.7000     NaN
# 25         NaN    NaN    NaN      NaN    NaN    NaN    NaN     NaN  0.7000
# 40         NaN    NaN    NaN      NaN    NaN  6.100    NaN     NaN     NaN
# 41         NaN    NaN    NaN      NaN    NaN    NaN  2.670     NaN     NaN
# 42         NaN    NaN    NaN      NaN    NaN    NaN    NaN  1.7600     NaN
# 43         NaN    NaN    NaN      NaN    NaN    NaN    NaN     NaN  0.7200
# 57         NaN    NaN    NaN      NaN    NaN  6.260    NaN     NaN     NaN
# 58         NaN    NaN    NaN      NaN    NaN    NaN  2.620     NaN     NaN
# 59         NaN    NaN    NaN      NaN    NaN    NaN    NaN  1.7600     NaN
# 60         NaN    NaN    NaN      NaN    NaN    NaN    NaN     NaN  0.7500
# 74         NaN    NaN    NaN      NaN    NaN  6.080    NaN     NaN     NaN
# 75         NaN    NaN    NaN      NaN    NaN    NaN  2.680     NaN     NaN
# 76         NaN    NaN    NaN      NaN    NaN    NaN    NaN  1.7600     NaN
# 77         NaN    NaN    NaN      NaN    NaN    NaN    NaN     NaN  0.8800
# 102        NaN    NaN    NaN      NaN    NaN  4.486    NaN     NaN     NaN
# 103        NaN    NaN    NaN      NaN    NaN    NaN  1.410     NaN     NaN
# 104        NaN    NaN    NaN      NaN    NaN    NaN    NaN  0.5154     NaN
# 105        NaN    NaN    NaN      NaN    NaN    NaN    NaN     NaN  0.1581
# 111        NaN    NaN    NaN      NaN    NaN  4.824    NaN     NaN     NaN
# 112        NaN    NaN    NaN      NaN    NaN    NaN  2.003     NaN     NaN
# 113        NaN    NaN    NaN      NaN    NaN    NaN    NaN  0.7739     NaN
# 114        NaN    NaN    NaN      NaN    NaN    NaN    NaN     Na